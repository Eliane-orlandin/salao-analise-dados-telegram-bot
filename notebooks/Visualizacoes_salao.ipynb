# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file = pd.read_csv("../data/raw/Planilha_atendimentos_agosto24.csv", decimal=',')
file
# Out:
#           Data  Nome do Cliente             Serviço    Profissional  \
# 0   01/09/2024        Ana Souza     Corte de Cabelo  Maria Oliveira
# 1   02/09/2024       João Silva               Barba    Pedro Santos
# 2   03/09/2024    Carla Menezes  Escova Progressiva       Ana Paula
# 3   04/09/2024    Fernanda Lima           Coloração  Maria Oliveira
# 4   05/09/2024   Marcos Andrade       Corte e Barba    Pedro Santos
# 5   06/09/2024    Laura Martins  Hidratação Capilar       Ana Paula
# 6   07/09/2024     Tiago Borges     Corte de Cabelo    Pedro Santos
# 7   08/09/2024     Marina Costa               Luzes  Maria Oliveira
# 8   09/09/2024   Eduardo Vieira     Corte de Cabelo    Pedro Santos
# 9   10/09/2024  Beatriz Freitas            Manicure   Juliana Silva
# 10  11/09/2024  Rafael Oliveira       Corte e Barba    Pedro Santos
# 11  12/09/2024  Patrícia Santos              Escova       Ana Paula
# 12  13/09/2024   Roberto Mendes           Coloração  Maria Oliveira
# 13  14/09/2024    Lucas Almeida               Barba    Pedro Santos
# 14  15/09/2024  Daniela Pereira     Corte de Cabelo       Ana Paula
#
#     Valor (R$) Forma de Pagamento
# 0           80  Cartão de Crédito
# 1           50           Dinheiro
# 2          250   Cartão de Débito
# 3          180                Pix
# 4          120           Dinheiro
# 5           90   Cartão de Débito
# 6           70  Cartão de Crédito
# 7          300  Cartão de Crédito
# 8           80                Pix
# 9           50   Cartão de Débito
# 10         110           Dinheiro
# 11          60  Cartão de Crédito
# 12         200   Cartão de Débito
# 13          50                Pix
# 14          90           Dinheiro

# %%
print(file.head())
# Out:
#          Data Nome do Cliente             Serviço    Profissional  Valor (R$)  \
# 0  01/09/2024       Ana Souza     Corte de Cabelo  Maria Oliveira          80
# 1  02/09/2024      João Silva               Barba    Pedro Santos          50
# 2  03/09/2024   Carla Menezes  Escova Progressiva       Ana Paula         250
# 3  04/09/2024   Fernanda Lima           Coloração  Maria Oliveira         180
# 4  05/09/2024  Marcos Andrade       Corte e Barba    Pedro Santos         120
#
#   Forma de Pagamento
# 0  Cartão de Crédito
# 1           Dinheiro
# 2   Cartão de Débito
# 3                Pix
# 4           Dinheiro

# %%
print(file.columns)
# Out:
# Index(['Data', 'Nome do Cliente', 'Serviço', 'Profissional', 'Valor (R$)',
#        'Forma de Pagamento'],
#       dtype='object')

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Data                15 non-null     object
#  1   Nome do Cliente     15 non-null     object
#  2   Serviço             15 non-null     object
#  3   Profissional        15 non-null     object
#  4   Valor (R$)          15 non-null     int64
#  5   Forma de Pagamento  15 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 852.0+ bytes

# %%
resultado = file.groupby(["Serviço"]).mean(numeric_only=True)

# %%
print(resultado)
# Out:
#                     Valor (R$)
# Serviço
# Barba                     50.0
# Coloração                190.0
# Corte de Cabelo           80.0
# Corte e Barba            115.0
# Escova                    60.0
# Escova Progressiva       250.0
# Hidratação Capilar        90.0
# Luzes                    300.0
# Manicure                  50.0

# %%
receita_por_pagamento = file.groupby('Forma de Pagamento')['Valor (R$)'].sum()
print(receita_por_pagamento)

plt.figure(figsize=(10, 6))
receita_por_pagamento.plot(kind='bar', color='skyblue')
plt.title('Receita Total por Forma de Pagamento')
plt.xlabel('Forma de Pagamento')
plt.ylabel('Receita (R$)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Forma de Pagamento
# Cartão de Crédito    510
# Cartão de Débito     590
# Dinheiro             370
# Pix                  310
# Name: Valor (R$), dtype: int64

# %%
servicos_populares = file['Serviço'].value_counts()
print(servicos_populares)

plt.figure(figsize=(12, 8))
servicos_populares.plot(kind='bar', color='lightgreen')
plt.title('Serviços Mais Populares')
plt.xlabel('Serviço')
plt.ylabel('Número de Solicitações')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Serviço
# Corte de Cabelo       4
# Barba                 2
# Coloração             2
# Corte e Barba         2
# Escova Progressiva    1
# Hidratação Capilar    1
# Luzes                 1
# Manicure              1
# Escova                1
# Name: count, dtype: int64

# %%
receita_por_profissional = file.groupby('Profissional')['Valor (R$)'].sum()
print(receita_por_profissional)

plt.figure(figsize=(12, 8))
receita_por_profissional.plot(kind='bar', color='salmon')
plt.title('Receita Total por Profissional')
plt.xlabel('Profissional')
plt.ylabel('Receita (R$)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Profissional
# Ana Paula         490
# Juliana Silva      50
# Maria Oliveira    760
# Pedro Santos      480
# Name: Valor (R$), dtype: int64
